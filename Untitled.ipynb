# %%
import requests
from bs4 import BeautifulSoup as bs

url = 'https://kmong.com/category/6?page=1'
res = requests.get(url).text
soup = bs(res, 'html.parser')
product_list = soup.select('#gigAB > div > div > div')

# %%
# !pip install requests
# Out:
# Collecting requests
#   Using cached https://files.pythonhosted.org/packages/7d/e3/20f3d364d6c8e5d2353c72a67778eb189176f08e873c9900e10c0287b84b/requests-2.21.0-py2.py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\playdata\anaconda3\envs\djproject\lib\site-packages (from requests) (2018.11.29)
# Collecting chardet<3.1.0,>=3.0.2 (from requests)
#   Using cached https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl
# Collecting urllib3<1.25,>=1.21.1 (from requests)
#   Using cached https://files.pythonhosted.org/packages/62/00/ee1d7de624db8ba7090d1226aebefab96a2c71cd5cfa7629d6ad3f61b79e/urllib3-1.24.1-py2.py3-none-any.whl
# Collecting idna<2.9,>=2.5 (from requests)
#   Using cached https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl
# Installing collected packages: chardet, urllib3, idna, requests
# Successfully installed chardet-3.0.4 idna-2.8 requests-2.21.0 urllib3-1.24.1

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Using cached https://files.pythonhosted.org/packages/1d/5d/3260694a59df0ec52f8b4883f5d23b130bc237602a1411fa670eae12351e/beautifulsoup4-4.7.1-py3-none-any.whl
# Collecting soupsieve>=1.2 (from beautifulsoup4->bs4)
#   Using cached https://files.pythonhosted.org/packages/77/78/bca00cc9fa70bba1226ee70a42bf375c4e048fe69066a0d9b5e69bc2a79a/soupsieve-1.8-py2.py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\Playdata\AppData\Local\pip\Cache\wheels\a0\b0\b2\4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.7.1 bs4-0.0.1 soupsieve-1.8

# %%
from kmong.models import Outsourcing

for product in product_list:
    name = product.find("img", {"class":"gig-list-user-profile"})['title']
    title = product.find("img", {"class":"width-100"})['title']
    img_src = product.find("img", {"class":"width-100"})['src']
    detail_link = product.find("a", {"class":"plain"})['href']
    price = (product.find("span", {"class":"tahoma"}).text).replace(",", "")
    Outsourcing.objects.create(name=name, title=title, 
    img_src=img_src, detail_link=detail_link, price=price)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\backends\utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      84             else:
# ---> 85                 return self.cursor.execute(sql, params)
#      86
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\backends\mysql\base.py in execute(self, query, args)
#      70             # args is None means no string interpolation
# ---> 71             return self.cursor.execute(query, args)
#      72         except Database.OperationalError as e:
#
# ~\Anaconda3\envs\djproject\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#
# ~\Anaconda3\envs\djproject\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     311         self._result = None
# --> 312         db.query(q)
#     313         self._do_get_result(db)
#
# ~\Anaconda3\envs\djproject\lib\site-packages\MySQLdb\connections.py in query(self, query)
#     223             query = bytes(query)
# --> 224         _mysql.connection.query(self, query)
#     225
#
# OperationalError: (1366, "Incorrect string value: '\\xEB\\xA9\\x94\\xEC\\x9D\\xB4...' for column 'name' at row 1")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-11-328f42593a58> in <module>
#       8     price = (product.find("span", {"class":"tahoma"}).text).replace(",", "")
#       9     Outsourcing.objects.create(name=name, title=title,
# ---> 10     img_src=img_src, detail_link=detail_link, price=price)
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\models\manager.py in manager_method(self, *args, **kwargs)
#      80         def create_method(name, method):
#      81             def manager_method(self, *args, **kwargs):
# ---> 82                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      83             manager_method.__name__ = method.__name__
#      84             manager_method.__doc__ = method.__doc__
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\models\query.py in create(self, **kwargs)
#     411         obj = self.model(**kwargs)
#     412         self._for_write = True
# --> 413         obj.save(force_insert=True, using=self.db)
#     414         return obj
#     415
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\models\base.py in save(self, force_insert, force_update, using, update_fields)
#     716
#     717         self.save_base(using=using, force_insert=force_insert,
# --> 718                        force_update=force_update, update_fields=update_fields)
#     719     save.alters_data = True
#     720
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\models\base.py in save_base(self, raw, force_insert, force_update, using, update_fields)
#     746             if not raw:
#     747                 self._save_parents(cls, using, update_fields)
# --> 748             updated = self._save_table(raw, cls, force_insert, force_update, using, update_fields)
#     749         # Store the database on which the object was saved
#     750         self._state.db = using
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\models\base.py in _save_table(self, raw, cls, force_insert, force_update, using, update_fields)
#     829
#     830             update_pk = meta.auto_field and not pk_set
# --> 831             result = self._do_insert(cls._base_manager, using, fields, update_pk, raw)
#     832             if update_pk:
#     833                 setattr(self, meta.pk.attname, result)
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\models\base.py in _do_insert(self, manager, using, fields, update_pk, raw)
#     867         """
#     868         return manager._insert([self], fields=fields, return_id=update_pk,
# --> 869                                using=using, raw=raw)
#     870
#     871     def delete(self, using=None, keep_parents=False):
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\models\manager.py in manager_method(self, *args, **kwargs)
#      80         def create_method(name, method):
#      81             def manager_method(self, *args, **kwargs):
# ---> 82                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      83             manager_method.__name__ = method.__name__
#      84             manager_method.__doc__ = method.__doc__
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\models\query.py in _insert(self, objs, fields, return_id, raw, using)
#    1134         query = sql.InsertQuery(self.model)
#    1135         query.insert_values(fields, objs, raw=raw)
# -> 1136         return query.get_compiler(using=using).execute_sql(return_id)
#    1137     _insert.alters_data = True
#    1138     _insert.queryset_only = False
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\models\sql\compiler.py in execute_sql(self, return_id)
#    1287         with self.connection.cursor() as cursor:
#    1288             for sql, params in self.as_sql():
# -> 1289                 cursor.execute(sql, params)
#    1290             if not return_id:
#    1291                 return
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      98         start = time()
#      99         try:
# --> 100             return super().execute(sql, params)
#     101         finally:
#     102             stop = time()
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      66
#      67     def execute(self, sql, params=None):
# ---> 68         return self._execute_with_wrappers(sql, params, many=False, executor=self._execute)
#      69
#      70     def executemany(self, sql, param_list):
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\backends\utils.py in _execute_with_wrappers(self, sql, params, many, executor)
#      75         for wrapper in reversed(self.db.execute_wrappers):
#      76             executor = functools.partial(wrapper, executor)
# ---> 77         return executor(sql, params, many, context)
#      78
#      79     def _execute(self, sql, params, *ignored_wrapper_args):
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\backends\utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83                 return self.cursor.execute(sql)
#      84             else:
# ---> 85                 return self.cursor.execute(sql, params)
#      86
#      87     def _executemany(self, sql, param_list, *ignored_wrapper_args):
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\utils.py in __exit__(self, exc_type, exc_value, traceback)
#      87                 if dj_exc_type not in (DataError, IntegrityError):
#      88                     self.wrapper.errors_occurred = True
# ---> 89                 raise dj_exc_value.with_traceback(traceback) from exc_value
#      90
#      91     def __call__(self, func):
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\backends\utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83                 return self.cursor.execute(sql)
#      84             else:
# ---> 85                 return self.cursor.execute(sql, params)
#      86
#      87     def _executemany(self, sql, param_list, *ignored_wrapper_args):
#
# ~\Anaconda3\envs\djproject\lib\site-packages\django\db\backends\mysql\base.py in execute(self, query, args)
#      69         try:
#      70             # args is None means no string interpolation
# ---> 71             return self.cursor.execute(query, args)
#      72         except Database.OperationalError as e:
#      73             # Map some error codes to IntegrityError, since they seem to be
#
# ~\Anaconda3\envs\djproject\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     204
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#     208
#
# ~\Anaconda3\envs\djproject\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     310         db = self._get_db()
#     311         self._result = None
# --> 312         db.query(q)
#     313         self._do_get_result(db)
#     314         self._post_get_result()
#
# ~\Anaconda3\envs\djproject\lib\site-packages\MySQLdb\connections.py in query(self, query)
#     222         if isinstance(query, bytearray):
#     223             query = bytes(query)
# --> 224         _mysql.connection.query(self, query)
#     225
#     226     def _bytes_literal(self, bs):
#
# OperationalError: (1366, "Incorrect string value: '\\xEB\\xA9\\x94\\xEC\\x9D\\xB4...' for column 'name' at row 1")
